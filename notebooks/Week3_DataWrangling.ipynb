# %% [markdown]
# # Week 3: Data Wrangling

# %%
# We are setting up the environment with all the packages we could possibly need
# For pandas documentation, see https://pandas.pydata.org/pandas-docs/stable/api.html#dataframe
# For matplotlib documentation, see https://matplotlib.org/api/pyplot_summary.html

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# We are reading the data in from the URL at which they are stored.

# %%
url = "https://raw.githubusercontent.com/shstreuber/Data-Mining/master/data/adult.data.simplified.csv"
adult = pd.read_csv(url)
adult
# Out:
#        age         workclass     education  educationyears  \
# 0       39         State-gov     Bachelors              13
# 1       50  Self-emp-not-inc     Bachelors              13
# 2       38           Private       HS-grad               9
# 3       53           Private          11th               7
# 4       28           Private     Bachelors              13
# 5       37           Private       Masters              14
# 6       49           Private           9th               5
# 7       52  Self-emp-not-inc       HS-grad               9
# 8       31           Private       Masters              14
# 9       42           Private     Bachelors              13
# 10      37           Private  Some-college              10
# 11      30         State-gov     Bachelors              13
# 12      23           Private     Bachelors              13
# 13      32           Private    Assoc-acdm              12
# 14      40           Private     Assoc-voc              11
# 15      34           Private       7th-8th               4
# 16      25  Self-emp-not-inc       HS-grad               9
# 17      32           Private       HS-grad               9
# 18      38           Private          11th               7
# 19      43  Self-emp-not-inc       Masters              14
# 20      40           Private     Doctorate              16
# 21      54           Private       HS-grad               9
# 22      35       Federal-gov           9th               5
# 23      43           Private          11th               7
# 24      59           Private       HS-grad               9
# 25      56         Local-gov     Bachelors              13
# 26      19           Private       HS-grad               9
# 27      54                 ?  Some-college              10
# 28      39           Private       HS-grad               9
# 29      49           Private       HS-grad               9
# ...    ...               ...           ...             ...
# 32531   30                 ?     Bachelors              13
# 32532   34           Private     Doctorate              16
# 32533   54           Private     Bachelors              13
# 32534   37           Private  Some-college              10
# 32535   22           Private          12th               8
# 32536   34           Private     Bachelors              13
# 32537   30           Private       HS-grad               9
# 32538   38           Private     Bachelors              13
# 32539   71                 ?     Doctorate              16
# 32540   45         State-gov       HS-grad               9
# 32541   41                 ?       HS-grad               9
# 32542   72                 ?       HS-grad               9
# 32543   45         Local-gov    Assoc-acdm              12
# 32544   31           Private       Masters              14
# 32545   39         Local-gov    Assoc-acdm              12
# 32546   37           Private    Assoc-acdm              12
# 32547   43           Private       HS-grad               9
# 32548   65  Self-emp-not-inc   Prof-school              15
# 32549   43         State-gov  Some-college              10
# 32550   43  Self-emp-not-inc  Some-college              10
# 32551   32           Private          10th               6
# 32552   43           Private     Assoc-voc              11
# 32553   32           Private       Masters              14
# 32554   53           Private       Masters              14
# 32555   22           Private  Some-college              10
# 32556   27           Private    Assoc-acdm              12
# 32557   40           Private       HS-grad               9
# 32558   58           Private       HS-grad               9
# 32559   22           Private       HS-grad               9
# 32560   52      Self-emp-inc       HS-grad               9
#
#                maritalstatus         occupation    relationship  \
# 0              Never-married       Adm-clerical   Not-in-family
# 1         Married-civ-spouse    Exec-managerial         Husband
# 2                   Divorced  Handlers-cleaners   Not-in-family
# 3         Married-civ-spouse  Handlers-cleaners         Husband
# 4         Married-civ-spouse     Prof-specialty            Wife
# 5         Married-civ-spouse    Exec-managerial            Wife
# 6      Married-spouse-absent      Other-service   Not-in-family
# 7         Married-civ-spouse    Exec-managerial         Husband
# 8              Never-married     Prof-specialty   Not-in-family
# 9         Married-civ-spouse    Exec-managerial         Husband
# 10        Married-civ-spouse    Exec-managerial         Husband
# 11        Married-civ-spouse     Prof-specialty         Husband
# 12             Never-married       Adm-clerical       Own-child
# 13             Never-married              Sales   Not-in-family
# 14        Married-civ-spouse       Craft-repair         Husband
# 15        Married-civ-spouse   Transport-moving         Husband
# 16             Never-married    Farming-fishing       Own-child
# 17             Never-married  Machine-op-inspct       Unmarried
# 18        Married-civ-spouse              Sales         Husband
# 19                  Divorced    Exec-managerial       Unmarried
# 20        Married-civ-spouse     Prof-specialty         Husband
# 21                 Separated      Other-service       Unmarried
# 22        Married-civ-spouse    Farming-fishing         Husband
# 23        Married-civ-spouse   Transport-moving         Husband
# 24                  Divorced       Tech-support       Unmarried
# 25        Married-civ-spouse       Tech-support         Husband
# 26             Never-married       Craft-repair       Own-child
# 27        Married-civ-spouse                  ?         Husband
# 28                  Divorced    Exec-managerial   Not-in-family
# 29        Married-civ-spouse       Craft-repair         Husband
# ...                      ...                ...             ...
# 32531          Never-married                  ?   Not-in-family
# 32532     Married-civ-spouse     Prof-specialty         Husband
# 32533     Married-civ-spouse    Exec-managerial         Husband
# 32534               Divorced       Adm-clerical       Unmarried
# 32535          Never-married    Protective-serv       Own-child
# 32536          Never-married    Exec-managerial   Not-in-family
# 32537          Never-married       Craft-repair   Not-in-family
# 32538               Divorced     Prof-specialty       Unmarried
# 32539     Married-civ-spouse                  ?         Husband
# 32540              Separated       Adm-clerical       Own-child
# 32541              Separated                  ?   Not-in-family
# 32542     Married-civ-spouse                  ?         Husband
# 32543               Divorced     Prof-specialty       Unmarried
# 32544               Divorced      Other-service   Not-in-family
# 32545     Married-civ-spouse       Adm-clerical            Wife
# 32546               Divorced       Tech-support   Not-in-family
# 32547     Married-civ-spouse  Machine-op-inspct         Husband
# 32548          Never-married     Prof-specialty   Not-in-family
# 32549               Divorced       Adm-clerical  Other-relative
# 32550     Married-civ-spouse       Craft-repair         Husband
# 32551     Married-civ-spouse  Handlers-cleaners         Husband
# 32552     Married-civ-spouse              Sales         Husband
# 32553          Never-married       Tech-support   Not-in-family
# 32554     Married-civ-spouse    Exec-managerial         Husband
# 32555          Never-married    Protective-serv   Not-in-family
# 32556     Married-civ-spouse       Tech-support            Wife
# 32557     Married-civ-spouse  Machine-op-inspct         Husband
# 32558                Widowed       Adm-clerical       Unmarried
# 32559          Never-married       Adm-clerical       Own-child
# 32560     Married-civ-spouse    Exec-managerial            Wife
#
#                      race     sex  hoursperweek        nativecountry  \
# 0                   White    Male            40        United-States
# 1                   White    Male            13        United-States
# 2                   White    Male            40        United-States
# 3                   Black    Male            40        United-States
# 4                   Black  Female            40                 Cuba
# 5                   White  Female            40        United-States
# 6                   Black  Female            16              Jamaica
# 7                   White    Male            45        United-States
# 8                   White  Female            50        United-States
# 9                   White    Male            40        United-States
# 10                  Black    Male            80        United-States
# 11     Asian-Pac-Islander    Male            40                India
# 12                  White  Female            30        United-States
# 13                  Black    Male            50        United-States
# 14     Asian-Pac-Islander    Male            40                    ?
# 15     Amer-Indian-Eskimo    Male            45               Mexico
# 16                  White    Male            35        United-States
# 17                  White    Male            40        United-States
# 18                  White    Male            50        United-States
# 19                  White  Female            45        United-States
# 20                  White    Male            60        United-States
# 21                  Black  Female            20        United-States
# 22                  Black    Male            40        United-States
# 23                  White    Male            40        United-States
# 24                  White  Female            40        United-States
# 25                  White    Male            40        United-States
# 26                  White    Male            40        United-States
# 27     Asian-Pac-Islander    Male            60  South-Africa-Africa
# 28                  White    Male            80        United-States
# 29                  White    Male            40        United-States
# ...                   ...     ...           ...                  ...
# 32531  Asian-Pac-Islander  Female            99        United-States
# 32532               White    Male            60        United-States
# 32533  Asian-Pac-Islander    Male            50                Japan
# 32534               White  Female            39        United-States
# 32535               Black    Male            35        United-States
# 32536               White  Female            55        United-States
# 32537               Black    Male            46        United-States
# 32538               Black  Female            45        United-States
# 32539               White    Male            10        United-States
# 32540               White  Female            40        United-States
# 32541               Black  Female            32        United-States
# 32542               White    Male            25        United-States
# 32543               White  Female            48        United-States
# 32544               Other  Female            30        United-States
# 32545               White  Female            20        United-States
# 32546               White  Female            40        United-States
# 32547               White    Male            40               Mexico
# 32548               White    Male            60        United-States
# 32549               White  Female            40        United-States
# 32550               White    Male            50        United-States
# 32551  Amer-Indian-Eskimo    Male            40        United-States
# 32552               White    Male            45        United-States
# 32553  Asian-Pac-Islander    Male            11               Taiwan
# 32554               White    Male            40        United-States
# 32555               White    Male            40        United-States
# 32556               White  Female            38        United-States
# 32557               White    Male            40        United-States
# 32558               White  Female            40        United-States
# 32559               White    Male            20        United-States
# 32560               White  Female            40        United-States
#
#        incomeUSD
# 0          43747
# 1          38907
# 2          25055
# 3          26733
# 4          23429
# 5          36970
# 6          45531
# 7         103612
# 8          64478
# 9          87200
# 10        167514
# 11        189843
# 12         35813
# 13         22373
# 14        115887
# 15         26294
# 16         36496
# 17         21612
# 18         23383
# 19        137281
# 20         96050
# 21         45278
# 22         37318
# 23         46082
# 24         43226
# 25        178573
# 26         20810
# 27        134092
# 28         22624
# 29         34644
# ...          ...
# 32531      38437
# 32532     127449
# 32533     198066
# 32534      48904
# 32535      24521
# 32536     122333
# 32537      27847
# 32538      68279
# 32539     137903
# 32540      38437
# 32541      49196
# 32542      41315
# 32543      47033
# 32544      40654
# 32545     128517
# 32546      29771
# 32547      35346
# 32548      21739
# 32549      36641
# 32550      23296
# 32551      42290
# 32552      45317
# 32553      33637
# 32554     135378
# 32555      44367
# 32556      41636
# 32557      87811
# 32558      46073
# 32559      29618
# 32560     196782
#
# [32561 rows x 12 columns]

# %% [markdown]
# ## Slicing in Pandas
# Slicing and subsetting are related. While Slicing requires indexing, which we will see below iwht the iloc operator, subsetting does not require indexing. Subsetting is explained here: https://cmdlinetips.com/2018/02/how-to-subset-pandas-dataframe-based-on-values-of-a-column/
# We will select what we need from both and apply it to the adult dataframe.

# %%
# Looking at only the first 5 rows
adult.iloc[0:5,]
# Out:
#    age         workclass  education  educationyears       maritalstatus  \
# 0   39         State-gov  Bachelors              13       Never-married
# 1   50  Self-emp-not-inc  Bachelors              13  Married-civ-spouse
# 2   38           Private    HS-grad               9            Divorced
# 3   53           Private       11th               7  Married-civ-spouse
# 4   28           Private  Bachelors              13  Married-civ-spouse
#
#           occupation   relationship   race     sex  hoursperweek  \
# 0       Adm-clerical  Not-in-family  White    Male            40
# 1    Exec-managerial        Husband  White    Male            13
# 2  Handlers-cleaners  Not-in-family  White    Male            40
# 3  Handlers-cleaners        Husband  Black    Male            40
# 4     Prof-specialty           Wife  Black  Female            40
#
#    nativecountry  incomeUSD
# 0  United-States      43747
# 1  United-States      38907
# 2  United-States      25055
# 3  United-States      26733
# 4           Cuba      23429

# %%
# Looking at only those rows with people who are 90 years old
# Try this out with <= 90 or >= 75, as well
adult[adult['age'] == 90]
# Out:
#        age         workclass     education  educationyears  \
# 222     90           Private       HS-grad               9
# 1040    90           Private       HS-grad               9
# 1935    90           Private     Bachelors              13
# 2303    90           Private  Some-college              10
# 2891    90           Private  Some-college              10
# 4070    90           Private          11th               7
# 4109    90                 ?     Bachelors              13
# 5104    90           Private  Some-college              10
# 5272    90           Private           9th               5
# 5370    90         Local-gov       Masters              14
# 5406    90           Private       Masters              14
# 6232    90  Self-emp-not-inc     Bachelors              13
# 6624    90           Private          11th               7
# 8806    90           Private   Prof-school              15
# 8963    90                 ?       HS-grad               9
# 8973    90           Private     Bachelors              13
# 10210   90  Self-emp-not-inc  Some-college              10
# 10545   90           Private       HS-grad               9
# 11512   90           Private       HS-grad               9
# 11731   90                 ?       HS-grad               9
# 11996   90           Private     Bachelors              13
# 12451   90                 ?  Some-college              10
# 12975   90           Private          10th               6
# 14159   90         Local-gov    Assoc-acdm              12
# 15356   90           Private       HS-grad               9
# 15892   90           Private     Bachelors              13
# 18277   90           Private     Bachelors              13
# 18413   90           Private     Bachelors              13
# 18725   90         Local-gov       HS-grad               9
# 18832   90           Private       Masters              14
# 19212   90           Private  Some-college              10
# 19489   90           Private       HS-grad               9
# 19747   90           Private       7th-8th               4
# 20610   90           Private       Masters              14
# 22220   90           Private     Bachelors              13
# 24043   90  Self-emp-not-inc       HS-grad               9
# 24238   90                 ?       1st-4th               2
# 25303   90                 ?       7th-8th               4
# 28463   90       Federal-gov       HS-grad               9
# 31030   90           Private       HS-grad               9
# 31696   90                 ?       HS-grad               9
# 32277   90           Private       HS-grad               9
# 32367   90         Local-gov       7th-8th               4
#
#             maritalstatus         occupation    relationship  \
# 222         Never-married      Other-service   Not-in-family
# 1040        Never-married      Other-service   Not-in-family
# 1935   Married-civ-spouse    Exec-managerial         Husband
# 2303        Never-married      Other-service   Not-in-family
# 2891            Separated       Adm-clerical       Own-child
# 4070        Never-married  Handlers-cleaners       Own-child
# 4109              Widowed                  ?  Other-relative
# 5104        Never-married      Other-service   Not-in-family
# 5272        Never-married       Adm-clerical   Not-in-family
# 5370   Married-civ-spouse    Exec-managerial         Husband
# 5406        Never-married    Exec-managerial   Not-in-family
# 6232   Married-civ-spouse     Prof-specialty         Husband
# 6624   Married-civ-spouse       Craft-repair         Husband
# 8806   Married-civ-spouse     Prof-specialty         Husband
# 8963              Widowed                  ?   Not-in-family
# 8973   Married-civ-spouse              Sales         Husband
# 10210  Married-civ-spouse    Farming-fishing         Husband
# 10545  Married-civ-spouse       Craft-repair         Husband
# 11512       Never-married      Other-service       Own-child
# 11731             Widowed                  ?   Not-in-family
# 11996       Never-married    Exec-managerial   Not-in-family
# 12451       Never-married                  ?       Own-child
# 12975  Married-civ-spouse    Exec-managerial         Husband
# 14159  Married-civ-spouse       Adm-clerical         Husband
# 15356             Widowed   Transport-moving       Unmarried
# 15892  Married-civ-spouse    Exec-managerial            Wife
# 18277  Married-civ-spouse              Sales         Husband
# 18413       Never-married     Prof-specialty       Own-child
# 18725  Married-civ-spouse      Other-service         Husband
# 18832       Never-married    Exec-managerial       Own-child
# 19212            Divorced              Sales       Unmarried
# 19489  Married-civ-spouse  Machine-op-inspct         Husband
# 19747  Married-civ-spouse  Machine-op-inspct         Husband
# 20610  Married-civ-spouse     Prof-specialty            Wife
# 22220       Never-married     Prof-specialty   Not-in-family
# 24043       Never-married    Exec-managerial   Not-in-family
# 24238             Widowed                  ?   Not-in-family
# 25303           Separated                  ?   Not-in-family
# 28463  Married-civ-spouse       Craft-repair         Husband
# 31030  Married-civ-spouse  Machine-op-inspct         Husband
# 31696  Married-civ-spouse                  ?         Husband
# 32277             Widowed       Adm-clerical       Unmarried
# 32367  Married-civ-spouse    Protective-serv         Husband
#
#                      race     sex  hoursperweek        nativecountry  \
# 222                 Black    Male            40        United-States
# 1040                White  Female            40        United-States
# 1935                White    Male            45        United-States
# 2303   Asian-Pac-Islander    Male            35        United-States
# 2891                White  Female            40          Puerto-Rico
# 4070                White    Male            40        United-States
# 4109                White  Female            10        United-States
# 5104   Asian-Pac-Islander    Male            35        United-States
# 5272                White  Female            40        United-States
# 5370                White    Male            60        United-States
# 5406                Black    Male            50        United-States
# 6232                White    Male            50        United-States
# 6624                White    Male            40        United-States
# 8806                White    Male            72        United-States
# 8963                White  Female            40        United-States
# 8973                White    Male            15        United-States
# 10210               White    Male            40        United-States
# 10545               White    Male            50              Ecuador
# 11512               White  Female            24        United-States
# 11731               White    Male             4        United-States
# 11996               White    Male            55        United-States
# 12451  Asian-Pac-Islander    Male            10  South-Africa-Africa
# 12975               White    Male            40        United-States
# 14159  Asian-Pac-Islander    Male            20          Philippines
# 15356               White    Male            99        United-States
# 15892               White  Female            40              England
# 18277               White    Male            20                    ?
# 18413               White  Female            10        United-States
# 18725               White    Male            40        United-States
# 18832               White  Female            40        United-States
# 19212               Black  Female            37        United-States
# 19489               White    Male            40        United-States
# 19747               White    Male            40        United-States
# 20610               White  Female            40        United-States
# 22220  Asian-Pac-Islander    Male            40        United-States
# 24043               White    Male            12        United-States
# 24238               Black  Female            40        United-States
# 25303               White  Female            15        United-States
# 28463               White    Male            30        United-States
# 31030               White    Male            40        United-States
# 31696               White    Male            40        United-States
# 32277               White  Female            25        United-States
# 32367               White    Male            40        United-States
#
#        incomeUSD
# 222        36040
# 1040       24955
# 1935       43154
# 2303       29655
# 2891       20750
# 4070       47745
# 4109       28674
# 5104       24933
# 5272       40440
# 5370      119802
# 5406      124209
# 6232       22426
# 6624       26540
# 8806       60349
# 8963       27959
# 8973       97437
# 10210      29158
# 10545      57962
# 11512      38622
# 11731      24170
# 11996      35378
# 12451      36138
# 12975      48587
# 14159      20423
# 15356      35966
# 15892     169026
# 18277      28148
# 18413      42803
# 18725      32402
# 18832      41390
# 19212      46236
# 19489      39146
# 19747      27772
# 20610     114687
# 22220      29275
# 24043      39158
# 24238      46086
# 25303      23404
# 28463      30260
# 31030      47300
# 31696     144467
# 32277      49412
# 32367      27600

# %%
# If you are filtering for strings, the strings need to be in single or double quotes ''
adult[adult['education'] == 'Bachelors']
# Out:
#        age         workclass  education  educationyears  \
# 0       39         State-gov  Bachelors              13
# 1       50  Self-emp-not-inc  Bachelors              13
# 4       28           Private  Bachelors              13
# 9       42           Private  Bachelors              13
# 11      30         State-gov  Bachelors              13
# 12      23           Private  Bachelors              13
# 25      56         Local-gov  Bachelors              13
# 32      45           Private  Bachelors              13
# 41      53  Self-emp-not-inc  Bachelors              13
# 42      24           Private  Bachelors              13
# 45      57       Federal-gov  Bachelors              13
# 53      50       Federal-gov  Bachelors              13
# 60      30           Private  Bachelors              13
# 71      31           Private  Bachelors              13
# 72      29  Self-emp-not-inc  Bachelors              13
# 81      52           Private  Bachelors              13
# 94      34         Local-gov  Bachelors              13
# 101     44           Private  Bachelors              13
# 110     24           Private  Bachelors              13
# 121     40           Private  Bachelors              13
# 122     30           Private  Bachelors              13
# 123     29         State-gov  Bachelors              13
# 125     47           Private  Bachelors              13
# 133     37           Private  Bachelors              13
# 152     33           Private  Bachelors              13
# 156     23           Private  Bachelors              13
# 159     42           Private  Bachelors              13
# 173     27           Private  Bachelors              13
# 174     28         State-gov  Bachelors              13
# 179     33           Private  Bachelors              13
# ...    ...               ...        ...             ...
# 32341   74  Self-emp-not-inc  Bachelors              13
# 32344   34           Private  Bachelors              13
# 32347   36         State-gov  Bachelors              13
# 32348   44           Private  Bachelors              13
# 32371   49  Self-emp-not-inc  Bachelors              13
# 32373   22           Private  Bachelors              13
# 32383   28       Federal-gov  Bachelors              13
# 32393   43           Private  Bachelors              13
# 32399   42           Private  Bachelors              13
# 32408   30           Private  Bachelors              13
# 32418   26           Private  Bachelors              13
# 32419   36           Private  Bachelors              13
# 32420   23           Private  Bachelors              13
# 32424   35           Private  Bachelors              13
# 32428   39       Federal-gov  Bachelors              13
# 32433   41  Self-emp-not-inc  Bachelors              13
# 32439   23           Private  Bachelors              13
# 32455   36  Self-emp-not-inc  Bachelors              13
# 32458   36           Private  Bachelors              13
# 32459   85           Private  Bachelors              13
# 32461   24           Private  Bachelors              13
# 32464   45      Self-emp-inc  Bachelors              13
# 32502   35         Local-gov  Bachelors              13
# 32507   50           Private  Bachelors              13
# 32511   25         Local-gov  Bachelors              13
# 32530   35                 ?  Bachelors              13
# 32531   30                 ?  Bachelors              13
# 32533   54           Private  Bachelors              13
# 32536   34           Private  Bachelors              13
# 32538   38           Private  Bachelors              13
#
#                maritalstatus         occupation    relationship  \
# 0              Never-married       Adm-clerical   Not-in-family
# 1         Married-civ-spouse    Exec-managerial         Husband
# 4         Married-civ-spouse     Prof-specialty            Wife
# 9         Married-civ-spouse    Exec-managerial         Husband
# 11        Married-civ-spouse     Prof-specialty         Husband
# 12             Never-married       Adm-clerical       Own-child
# 25        Married-civ-spouse       Tech-support         Husband
# 32                  Divorced    Exec-managerial       Own-child
# 41        Married-civ-spouse     Prof-specialty         Husband
# 42        Married-civ-spouse       Tech-support         Husband
# 45        Married-civ-spouse     Prof-specialty         Husband
# 53                  Divorced    Exec-managerial   Not-in-family
# 60        Married-civ-spouse              Sales         Husband
# 71                 Separated              Sales       Own-child
# 72        Married-civ-spouse              Sales         Husband
# 81        Married-civ-spouse      Other-service         Husband
# 94        Married-civ-spouse    Protective-serv         Husband
# 101       Married-civ-spouse    Exec-managerial         Husband
# 110            Never-married              Sales  Other-relative
# 121       Married-civ-spouse    Exec-managerial         Husband
# 122            Never-married    Exec-managerial       Own-child
# 123       Married-civ-spouse     Prof-specialty         Husband
# 125       Married-civ-spouse    Exec-managerial            Wife
# 133       Married-civ-spouse              Sales         Husband
# 152            Never-married    Exec-managerial  Other-relative
# 156            Never-married  Handlers-cleaners   Not-in-family
# 159                Separated      Other-service  Other-relative
# 173            Never-married       Craft-repair   Not-in-family
# 174       Married-civ-spouse     Prof-specialty         Husband
# 179       Married-civ-spouse     Prof-specialty         Husband
# ...                      ...                ...             ...
# 32341                Widowed       Craft-repair   Not-in-family
# 32344  Married-spouse-absent       Adm-clerical   Not-in-family
# 32347     Married-civ-spouse       Adm-clerical            Wife
# 32348     Married-civ-spouse   Transport-moving         Husband
# 32371     Married-civ-spouse    Exec-managerial         Husband
# 32373          Never-married    Exec-managerial   Not-in-family
# 32383          Never-married     Prof-specialty   Not-in-family
# 32393          Never-married       Adm-clerical   Not-in-family
# 32399     Married-civ-spouse              Sales         Husband
# 32408          Never-married              Sales   Not-in-family
# 32418          Never-married     Prof-specialty   Not-in-family
# 32419     Married-civ-spouse    Exec-managerial         Husband
# 32420          Never-married    Exec-managerial   Not-in-family
# 32424     Married-civ-spouse    Exec-managerial         Husband
# 32428     Married-civ-spouse       Adm-clerical            Wife
# 32433     Married-civ-spouse     Prof-specialty         Husband
# 32439          Never-married     Prof-specialty       Own-child
# 32455     Married-civ-spouse              Sales         Husband
# 32458     Married-civ-spouse     Prof-specialty         Husband
# 32459     Married-civ-spouse    Exec-managerial         Husband
# 32461          Never-married  Machine-op-inspct   Not-in-family
# 32464     Married-civ-spouse    Exec-managerial         Husband
# 32502     Married-civ-spouse     Prof-specialty         Husband
# 32507     Married-civ-spouse     Prof-specialty         Husband
# 32511          Never-married       Adm-clerical       Own-child
# 32530     Married-civ-spouse                  ?            Wife
# 32531          Never-married                  ?   Not-in-family
# 32533     Married-civ-spouse    Exec-managerial         Husband
# 32536          Never-married    Exec-managerial   Not-in-family
# 32538               Divorced     Prof-specialty       Unmarried
#
#                      race     sex  hoursperweek  nativecountry  incomeUSD
# 0                   White    Male            40  United-States      43747
# 1                   White    Male            13  United-States      38907
# 4                   Black  Female            40           Cuba      23429
# 9                   White    Male            40  United-States      87200
# 11     Asian-Pac-Islander    Male            40          India     189843
# 12                  White  Female            30  United-States      35813
# 25                  White    Male            40  United-States     178573
# 32                  White    Male            40  United-States      40889
# 41                  White    Male            40  United-States      21545
# 42                  White    Male            50  United-States      36484
# 45                  Black    Male            40  United-States      59836
# 53                  White    Male            55  United-States     123893
# 60                  White    Male            40  United-States      30820
# 71                  Black  Female            40  United-States      33571
# 72                  White    Male            70  United-States     190337
# 81                  White    Male            40           Cuba      38723
# 94                  White    Male            40  United-States     155965
# 101                 White    Male            60  United-States      87135
# 110                 White    Male            40  United-States      43800
# 121                 White    Male            60  United-States      45867
# 122                 Black    Male            40        Germany      37137
# 123                 White    Male            50  United-States      85850
# 125                 White  Female            40  United-States      84898
# 133                 White    Male            50  United-States      29738
# 152    Asian-Pac-Islander  Female            40    Philippines      42226
# 156                 White    Male            40  United-States      32933
# 159                 Black    Male            50  United-States      43799
# 173                 White    Male            50  United-States      20076
# 174                 White    Male            40  United-States      87226
# 179                 White    Male            65  United-States      39286
# ...                   ...     ...           ...            ...        ...
# 32341               White    Male             8        Germany     114435
# 32344               White  Female            45  United-States      31107
# 32347               White  Female            20  United-States      74759
# 32348               White    Male            55  United-States      48967
# 32371               White    Male            60       Scotland      52341
# 32373               White  Female            40  United-States      31228
# 32383               White    Male            50  United-States      26976
# 32393               White    Male            40  United-States      34465
# 32399               White    Male            40  United-States      96331
# 32408               White    Male            40  United-States      27006
# 32418               White  Female            40  United-States      36935
# 32419               White    Male            55  United-States     104040
# 32420               White  Female            50  United-States      34590
# 32424               White    Male            45  United-States      30314
# 32428  Asian-Pac-Islander  Female            40    Philippines      23973
# 32433               White    Male            50  United-States      48256
# 32439               White    Male            40  United-States      44106
# 32455               White    Male            50  United-States     126359
# 32458               White    Male            45  United-States     159982
# 32459               White    Male             3         Poland      32233
# 32461               White  Female            32  United-States      27423
# 32464               White    Male            45  United-States      97179
# 32502               White    Male            50  United-States      46244
# 32507               White    Male            40  United-States      33819
# 32511               Black  Female            40  United-States      22967
# 32530               White  Female            55  United-States      50806
# 32531  Asian-Pac-Islander  Female            99  United-States      38437
# 32533  Asian-Pac-Islander    Male            50          Japan     198066
# 32536               White  Female            55  United-States     122333
# 32538               Black  Female            45  United-States      68279
#
# [5355 rows x 12 columns]

# %%
# Extracting the first 5 columns
adult.iloc[:,0:5]
# Out:
#        age         workclass     education  educationyears  \
# 0       39         State-gov     Bachelors              13
# 1       50  Self-emp-not-inc     Bachelors              13
# 2       38           Private       HS-grad               9
# 3       53           Private          11th               7
# 4       28           Private     Bachelors              13
# 5       37           Private       Masters              14
# 6       49           Private           9th               5
# 7       52  Self-emp-not-inc       HS-grad               9
# 8       31           Private       Masters              14
# 9       42           Private     Bachelors              13
# 10      37           Private  Some-college              10
# 11      30         State-gov     Bachelors              13
# 12      23           Private     Bachelors              13
# 13      32           Private    Assoc-acdm              12
# 14      40           Private     Assoc-voc              11
# 15      34           Private       7th-8th               4
# 16      25  Self-emp-not-inc       HS-grad               9
# 17      32           Private       HS-grad               9
# 18      38           Private          11th               7
# 19      43  Self-emp-not-inc       Masters              14
# 20      40           Private     Doctorate              16
# 21      54           Private       HS-grad               9
# 22      35       Federal-gov           9th               5
# 23      43           Private          11th               7
# 24      59           Private       HS-grad               9
# 25      56         Local-gov     Bachelors              13
# 26      19           Private       HS-grad               9
# 27      54                 ?  Some-college              10
# 28      39           Private       HS-grad               9
# 29      49           Private       HS-grad               9
# ...    ...               ...           ...             ...
# 32531   30                 ?     Bachelors              13
# 32532   34           Private     Doctorate              16
# 32533   54           Private     Bachelors              13
# 32534   37           Private  Some-college              10
# 32535   22           Private          12th               8
# 32536   34           Private     Bachelors              13
# 32537   30           Private       HS-grad               9
# 32538   38           Private     Bachelors              13
# 32539   71                 ?     Doctorate              16
# 32540   45         State-gov       HS-grad               9
# 32541   41                 ?       HS-grad               9
# 32542   72                 ?       HS-grad               9
# 32543   45         Local-gov    Assoc-acdm              12
# 32544   31           Private       Masters              14
# 32545   39         Local-gov    Assoc-acdm              12
# 32546   37           Private    Assoc-acdm              12
# 32547   43           Private       HS-grad               9
# 32548   65  Self-emp-not-inc   Prof-school              15
# 32549   43         State-gov  Some-college              10
# 32550   43  Self-emp-not-inc  Some-college              10
# 32551   32           Private          10th               6
# 32552   43           Private     Assoc-voc              11
# 32553   32           Private       Masters              14
# 32554   53           Private       Masters              14
# 32555   22           Private  Some-college              10
# 32556   27           Private    Assoc-acdm              12
# 32557   40           Private       HS-grad               9
# 32558   58           Private       HS-grad               9
# 32559   22           Private       HS-grad               9
# 32560   52      Self-emp-inc       HS-grad               9
#
#                maritalstatus
# 0              Never-married
# 1         Married-civ-spouse
# 2                   Divorced
# 3         Married-civ-spouse
# 4         Married-civ-spouse
# 5         Married-civ-spouse
# 6      Married-spouse-absent
# 7         Married-civ-spouse
# 8              Never-married
# 9         Married-civ-spouse
# 10        Married-civ-spouse
# 11        Married-civ-spouse
# 12             Never-married
# 13             Never-married
# 14        Married-civ-spouse
# 15        Married-civ-spouse
# 16             Never-married
# 17             Never-married
# 18        Married-civ-spouse
# 19                  Divorced
# 20        Married-civ-spouse
# 21                 Separated
# 22        Married-civ-spouse
# 23        Married-civ-spouse
# 24                  Divorced
# 25        Married-civ-spouse
# 26             Never-married
# 27        Married-civ-spouse
# 28                  Divorced
# 29        Married-civ-spouse
# ...                      ...
# 32531          Never-married
# 32532     Married-civ-spouse
# 32533     Married-civ-spouse
# 32534               Divorced
# 32535          Never-married
# 32536          Never-married
# 32537          Never-married
# 32538               Divorced
# 32539     Married-civ-spouse
# 32540              Separated
# 32541              Separated
# 32542     Married-civ-spouse
# 32543               Divorced
# 32544               Divorced
# 32545     Married-civ-spouse
# 32546               Divorced
# 32547     Married-civ-spouse
# 32548          Never-married
# 32549               Divorced
# 32550     Married-civ-spouse
# 32551     Married-civ-spouse
# 32552     Married-civ-spouse
# 32553          Never-married
# 32554     Married-civ-spouse
# 32555          Never-married
# 32556     Married-civ-spouse
# 32557     Married-civ-spouse
# 32558                Widowed
# 32559          Never-married
# 32560     Married-civ-spouse
#
# [32561 rows x 5 columns]

# %%
# Constraining to the first 5 columns and first 5 rows
adult.iloc[0:5,0:5]
# Out:
#    age         workclass  education  educationyears       maritalstatus
# 0   39         State-gov  Bachelors              13       Never-married
# 1   50  Self-emp-not-inc  Bachelors              13  Married-civ-spouse
# 2   38           Private    HS-grad               9            Divorced
# 3   53           Private       11th               7  Married-civ-spouse
# 4   28           Private  Bachelors              13  Married-civ-spouse

# %%
# Selecting multiple columns at the same time extracts a new DataFrame from your existing DataFrame. 
# For selection of multiple columns, the syntax is: square-brace selection with a list of column names, 
# e.g. data[['column_name_1', 'column_name_2']]
adult[['age','education','sex']]
# Out:
#        age     education     sex
# 0       39     Bachelors    Male
# 1       50     Bachelors    Male
# 2       38       HS-grad    Male
# 3       53          11th    Male
# 4       28     Bachelors  Female
# 5       37       Masters  Female
# 6       49           9th  Female
# 7       52       HS-grad    Male
# 8       31       Masters  Female
# 9       42     Bachelors    Male
# 10      37  Some-college    Male
# 11      30     Bachelors    Male
# 12      23     Bachelors  Female
# 13      32    Assoc-acdm    Male
# 14      40     Assoc-voc    Male
# 15      34       7th-8th    Male
# 16      25       HS-grad    Male
# 17      32       HS-grad    Male
# 18      38          11th    Male
# 19      43       Masters  Female
# 20      40     Doctorate    Male
# 21      54       HS-grad  Female
# 22      35           9th    Male
# 23      43          11th    Male
# 24      59       HS-grad  Female
# 25      56     Bachelors    Male
# 26      19       HS-grad    Male
# 27      54  Some-college    Male
# 28      39       HS-grad    Male
# 29      49       HS-grad    Male
# ...    ...           ...     ...
# 32531   30     Bachelors  Female
# 32532   34     Doctorate    Male
# 32533   54     Bachelors    Male
# 32534   37  Some-college  Female
# 32535   22          12th    Male
# 32536   34     Bachelors  Female
# 32537   30       HS-grad    Male
# 32538   38     Bachelors  Female
# 32539   71     Doctorate    Male
# 32540   45       HS-grad  Female
# 32541   41       HS-grad  Female
# 32542   72       HS-grad    Male
# 32543   45    Assoc-acdm  Female
# 32544   31       Masters  Female
# 32545   39    Assoc-acdm  Female
# 32546   37    Assoc-acdm  Female
# 32547   43       HS-grad    Male
# 32548   65   Prof-school    Male
# 32549   43  Some-college  Female
# 32550   43  Some-college    Male
# 32551   32          10th    Male
# 32552   43     Assoc-voc    Male
# 32553   32       Masters    Male
# 32554   53       Masters    Male
# 32555   22  Some-college    Male
# 32556   27    Assoc-acdm  Female
# 32557   40       HS-grad    Male
# 32558   58       HS-grad  Female
# 32559   22       HS-grad    Male
# 32560   52       HS-grad  Female
#
# [32561 rows x 3 columns]

# %%
# Alternately, using numeric indexing with the iloc selector and a list of column numbers, e.g. data.iloc[:, [0,1,20,22]]
# This allows you to specify colums, as well
adult.iloc[0:5,[0,1,2,3,4]]
# Out:
#    age         workclass  education  educationyears       maritalstatus
# 0   39         State-gov  Bachelors              13       Never-married
# 1   50  Self-emp-not-inc  Bachelors              13  Married-civ-spouse
# 2   38           Private    HS-grad               9            Divorced
# 3   53           Private       11th               7  Married-civ-spouse
# 4   28           Private  Bachelors              13  Married-civ-spouse

# %%
# Reviewing the datatypes
adult.dtypes
# Out:
# age                int64
# workclass         object
# education         object
# educationyears     int64
# maritalstatus     object
# occupation        object
# relationship      object
# race              object
# sex               object
# hoursperweek       int64
# nativecountry     object
# incomeUSD          int64
# dtype: object

# %%
# Making a smaller dataframe with row 77 having ? in workclass and occupation
adult_small=adult.iloc[70:80,0:12]
adult_small
# Out:
#     age         workclass     education  educationyears       maritalstatus  \
# 70   19           Private  Some-college              10       Never-married
# 71   31           Private     Bachelors              13           Separated
# 72   29  Self-emp-not-inc     Bachelors              13  Married-civ-spouse
# 73   23           Private  Some-college              10       Never-married
# 74   79           Private  Some-college              10  Married-civ-spouse
# 75   27           Private       HS-grad               9       Never-married
# 76   40           Private    Assoc-acdm              12  Married-civ-spouse
# 77   67                 ?          10th               6  Married-civ-spouse
# 78   18           Private          11th               7       Never-married
# 79   31         Local-gov       7th-8th               4  Married-civ-spouse
#
#            occupation    relationship   race     sex  hoursperweek  \
# 70     Prof-specialty       Own-child  White    Male            32
# 71              Sales       Own-child  Black  Female            40
# 72              Sales         Husband  White    Male            70
# 73  Machine-op-inspct   Not-in-family  White    Male            40
# 74     Prof-specialty  Other-relative  White    Male            20
# 75      Other-service       Own-child  White    Male            40
# 76       Adm-clerical         Husband  White    Male            40
# 77                  ?         Husband  White    Male             2
# 78      Other-service       Own-child  White  Female            22
# 79    Farming-fishing         Husband  White    Male            40
#
#     nativecountry  incomeUSD
# 70  United-States      41013
# 71  United-States      33571
# 72  United-States     190337
# 73  United-States      23773
# 74  United-States      49908
# 75         Mexico      34334
# 76  United-States      47470
# 77  United-States      40188
# 78  United-States      44387
# 79  United-States      40938

# %%
# Some review from last week--adult.shape is equivalent to adult.dim in R, showing the dimensions of your dataset
adult_small.shape
# Out:
# (10, 12)

# %% [markdown]
# ## Data Transformation
# We want to transform a categorical attribute, in this case 'race', into a numeric datatype. The Python format for this operation is DataFrame.astype(dtype, copy=True, errors='raise')
# In our case, this would be something like
# adult_small.race.astype('int32')
# adult_small.race.astype('category')
# adult_small.race.astype('category', ordered=True)

# %%
adult_small.race.dtypes
# Out:
# dtype('O')

# %%
# Transform adult_small.race to numeric
# Since 'race' is of type object, we need to convert it to an ordered categorical attribute in order to obtain the 
# category index numbers
adult_small.race_num=adult_small['race'].astype('category')

# NOTE the error this will produce--R allows automatic column creation and indexing. Pandas does not. We gotta work!
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   after removing the cwd from sys.path.

# %%
# Create a new column first and copy the values from 'race' over.
adult_small['race_num'] = adult_small.race.values
adult_small.dtypes[['race','race_num']]
# Out:
# race        object
# race_num    object
# dtype: object

# %%
# Now we convert the race_num values to categorical and then to numeric
# adult_small.race_num=adult_small['race_num'].astype('category', ordered=True)
adult_small['race_num']= adult_small['race_num'].astype('category')
adult_small['race_num']= adult_small['race_num'].cat.codes
adult_small.dtypes[['race','race_num']]
# Out:
# race        object
# race_num      int8
# dtype: object

# %%
adult_small[['race','race_num']]
# Out:
#      race  race_num
# 70  White         1
# 71  Black         0
# 72  White         1
# 73  White         1
# 74  White         1
# 75  White         1
# 76  White         1
# 77  White         1
# 78  White         1
# 79  White         1

# %%
# Now we apply the transformation to the entire adult dataframe.
adult2=adult
adult2['race_num'] = adult2.race.values
adult2['race_num']= adult2['race_num'].astype('category')
adult2['race_num']= adult2['race_num'].cat.codes
adult2.dtypes[['race','race_num']]
# Out:
# race        object
# race_num      int8
# dtype: object

# %%
# We want to find out how pandas has transformed the string to numeric. 
# Making a new dataframe because it's so much easier to work with just 2 attributes
race=adult2[['race','race_num']]
race2=race.drop_duplicates()
race2.sort_values(by=['race_num'])

# As we can see, the index numbers are assigned on an alpha basis, just like in R!
# Out:
#                   race  race_num
# 15  Amer-Indian-Eskimo         0
# 11  Asian-Pac-Islander         1
# 3                Black         2
# 50               Other         3
# 0                White         4

# %% [markdown]
# ## De-Duplication
# See the example above. We used the drop_duplicates method.
# For more on drop_duplicates() see, https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop_duplicates.html

# %% [markdown]
# ## Substituting Values in Dataframes
# We will try out the df.replace method shown in https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html. This really convenient method works for strings and numeric values alike.

# %%
# Making a new dataframe. Let's look at the workclass attribute
adult3 = adult
adult3.workclass.unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
# We have a '?' value. Let's make this 'Unknown'
adult3[adult3['workclass'] == '?']
# Out:
#        age workclass     education  educationyears          maritalstatus  \
# 27      54         ?  Some-college              10     Married-civ-spouse
# 61      32         ?       7th-8th               4  Married-spouse-absent
# 69      25         ?  Some-college              10          Never-married
# 77      67         ?          10th               6     Married-civ-spouse
# 106     17         ?          10th               6          Never-married
# 128     35         ?       HS-grad               9     Married-civ-spouse
# 149     43         ?  Some-college              10               Divorced
# 154     52         ?       HS-grad               9               Divorced
# 160     68         ?       1st-4th               2               Divorced
# 187     53         ?     Bachelors              13               Divorced
# 201     19         ?       HS-grad               9          Never-married
# 221     64         ?       1st-4th               2               Divorced
# 226     60         ?          10th               6               Divorced
# 243     20         ?  Some-college              10          Never-married
# 266     19         ?  Some-college              10          Never-married
# 297     39         ?       Masters              14     Married-civ-spouse
# 312     19         ?  Some-college              10          Never-married
# 326     23         ?     Assoc-voc              11          Never-married
# 346     67         ?          11th               7     Married-civ-spouse
# 347     30         ?     Assoc-voc              11               Divorced
# 354     59         ?     Bachelors              13     Married-civ-spouse
# 397     20         ?       HS-grad               9          Never-married
# 408     28         ?  Some-college              10     Married-civ-spouse
# 430     80         ?       HS-grad               9                Widowed
# 431     17         ?          11th               7          Never-married
# 449     17         ?          11th               7          Never-married
# 459     32         ?  Some-college              10     Married-civ-spouse
# 471     22         ?  Some-college              10          Never-married
# 484     52         ?          12th               8          Never-married
# 486     63         ?       1st-4th               2     Married-civ-spouse
# ...    ...       ...           ...             ...                    ...
# 32016   62         ?       HS-grad               9     Married-civ-spouse
# 32039   24         ?       HS-grad               9          Never-married
# 32062   26         ?  Some-college              10          Never-married
# 32070   18         ?       HS-grad               9          Never-married
# 32073   65         ?       7th-8th               4     Married-civ-spouse
# 32075   27         ?       Masters              14          Never-married
# 32080   21         ?           9th               5          Never-married
# 32083   51         ?       HS-grad               9               Divorced
# 32088   21         ?       HS-grad               9          Never-married
# 32093   62         ?     Assoc-voc              11     Married-civ-spouse
# 32103   34         ?       7th-8th               4              Separated
# 32189   19         ?       HS-grad               9     Married-civ-spouse
# 32201   49         ?       HS-grad               9     Married-civ-spouse
# 32206   72         ?       5th-6th               3                Widowed
# 32275   20         ?  Some-college              10          Never-married
# 32291   59         ?  Some-college              10          Never-married
# 32310   21         ?  Some-college              10          Never-married
# 32317   63         ?  Some-college              10               Divorced
# 32335   18         ?          11th               7          Never-married
# 32343   66         ?       HS-grad               9                Widowed
# 32426   20         ?       HS-grad               9          Never-married
# 32477   49         ?          12th               8               Divorced
# 32490   60         ?           9th               5               Divorced
# 32494   82         ?       HS-grad               9          Never-married
# 32525   81         ?     Assoc-voc              11               Divorced
# 32530   35         ?     Bachelors              13     Married-civ-spouse
# 32531   30         ?     Bachelors              13          Never-married
# 32539   71         ?     Doctorate              16     Married-civ-spouse
# 32541   41         ?       HS-grad               9              Separated
# 32542   72         ?       HS-grad               9     Married-civ-spouse
#
#       occupation    relationship                race     sex  hoursperweek  \
# 27             ?         Husband  Asian-Pac-Islander    Male            60
# 61             ?   Not-in-family               White    Male            40
# 69             ?       Own-child               White    Male            40
# 77             ?         Husband               White    Male             2
# 106            ?       Own-child               White  Female            32
# 128            ?         Husband               White    Male            40
# 149            ?   Not-in-family               White  Female            40
# 154            ?   Not-in-family               White    Male            45
# 160            ?   Not-in-family               White  Female            20
# 187            ?   Not-in-family               White  Female            50
# 201            ?       Own-child               White    Male            40
# 221            ?   Not-in-family               White    Male            40
# 226            ?   Not-in-family  Amer-Indian-Eskimo  Female            10
# 243            ?       Own-child               White    Male            20
# 266            ?       Own-child               White    Male            24
# 297            ?            Wife  Asian-Pac-Islander  Female            40
# 312            ?       Own-child               Black  Female            25
# 326            ?       Own-child               Black  Female            15
# 346            ?         Husband               White    Male             8
# 347            ?       Unmarried               White  Female            40
# 354            ?         Husband               White    Male            40
# 397            ?  Other-relative               White  Female            35
# 408            ?            Wife               White  Female            40
# 430            ?   Not-in-family               White    Male            24
# 431            ?       Own-child               White    Male            40
# 449            ?       Own-child               White  Female             5
# 459            ?         Husband               White    Male            40
# 471            ?       Own-child               White    Male            40
# 484            ?  Other-relative               Black    Male            40
# 486            ?         Husband               White    Male            35
# ...          ...             ...                 ...     ...           ...
# 32016          ?         Husband               White    Male            40
# 32039          ?       Own-child               White    Male            40
# 32062          ?       Own-child  Asian-Pac-Islander    Male            40
# 32070          ?       Own-child               White  Female            20
# 32073          ?         Husband               White    Male            25
# 32075          ?   Not-in-family               Other  Female            40
# 32080          ?       Own-child               White    Male            42
# 32083          ?       Unmarried               Black  Female            40
# 32088          ?  Other-relative  Asian-Pac-Islander  Female            24
# 32093          ?         Husband               White    Male            40
# 32103          ?       Unmarried               Black  Female            40
# 32189          ?            Wife               White  Female            36
# 32201          ?            Wife               White  Female            60
# 32206          ?   Not-in-family               White  Female            40
# 32275          ?       Own-child               White  Female            30
# 32291          ?   Not-in-family               Black  Female            40
# 32310          ?       Own-child               White    Male            40
# 32317          ?   Not-in-family               White  Female             5
# 32335          ?       Own-child               White  Female            25
# 32343          ?       Unmarried               White  Female            40
# 32426          ?       Own-child               White    Male            40
# 32477          ?  Other-relative               Black    Male            40
# 32490          ?   Not-in-family               Black    Male            35
# 32494          ?   Not-in-family               White    Male             3
# 32525          ?       Unmarried               White  Female             1
# 32530          ?            Wife               White  Female            55
# 32531          ?   Not-in-family  Asian-Pac-Islander  Female            99
# 32539          ?         Husband               White    Male            10
# 32541          ?   Not-in-family               Black  Female            32
# 32542          ?         Husband               White    Male            25
#
#              nativecountry  incomeUSD  race_num
# 27     South-Africa-Africa     134092         1
# 61                       ?      21248         4
# 69           United-States      42975         4
# 77           United-States      40188         4
# 106          United-States      47415         4
# 128          United-States      36062         4
# 149          United-States      26514         4
# 154          United-States      84775         4
# 160          United-States      36395         4
# 187          United-States      34092         4
# 201                  Italy      23386         4
# 221          United-States      35099         4
# 226          United-States      45676         0
# 243          United-States      37199         4
# 266                 Canada      44458         4
# 297                      ?      26319         1
# 312          United-States      38706         2
# 326          United-States      37827         2
# 346          United-States      30333         4
# 347          United-States      37758         4
# 354          United-States     181063         4
# 397          United-States      37835         4
# 408          United-States     169796         4
# 430          United-States      28736         4
# 431          United-States      38513         4
# 449          United-States      45631         4
# 459          United-States      42091         4
# 471          United-States      32159         4
# 484          United-States      27455         2
# 486          United-States      48867         4
# ...                    ...        ...       ...
# 32016        United-States     101793         4
# 32039        United-States      41726         4
# 32062          Philippines      28468         1
# 32070        United-States      32362         4
# 32073        United-States      45052         4
# 32075                Japan      34987         3
# 32080        United-States      34145         4
# 32083        United-States      34005         2
# 32088        United-States      47810         1
# 32093               Canada      25458         4
# 32103        United-States      37842         2
# 32189        United-States      32758         4
# 32201        United-States      24271         4
# 32206        United-States      37659         4
# 32275        United-States      46427         4
# 32291        United-States      29774         2
# 32310        United-States      25618         4
# 32317        United-States      27003         4
# 32335        United-States      43652         4
# 32343        United-States      40861         4
# 32426        United-States      27533         4
# 32477        United-States      26801         2
# 32490        United-States      21230         2
# 32494        United-States      42783         4
# 32525                    ?      34119         4
# 32530        United-States      50806         4
# 32531        United-States      38437         1
# 32539        United-States     137903         4
# 32541        United-States      49196         2
# 32542        United-States      41315         4
#
# [1836 rows x 13 columns]

# %%
adult3.workclass.replace('?','Unknown', inplace=True)
adult3[adult3['workclass'] == '?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, educationyears, maritalstatus, occupation, relationship, race, sex, hoursperweek, nativecountry, incomeUSD, race_num]
# Index: []

# %%
# Looks like it worked. Let's check if the new value appears in the list of unique values.
adult3.workclass.unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', 'Unknown', 'Self-emp-inc', 'Without-pay',
#        'Never-worked'], dtype=object)

# %%
# But what about empty values like NA?
adult3.occupation.unique()
# Out:
# array(['Adm-clerical', 'Exec-managerial', 'Handlers-cleaners',
#        'Prof-specialty', 'Other-service', 'Sales', 'Craft-repair',
#        'Transport-moving', 'Farming-fishing', 'Machine-op-inspct',
#        'Tech-support', '?', 'Protective-serv', 'Armed-Forces',
#        'Priv-house-serv'], dtype=object)

# %%
# Let's set the '?' in occupation to NA, count how many NAs we have, and then replace this value with 'Unknown'

# %% [markdown]
# ## Dimensionality Reduction
# The goal of Dimensionality Reduction is to make our dataset smaller. This can happen as follows:
# - Eliminate attributes that are bascially duplicates of one another
# - Aggregate similar attribute levels in one level
# - Normalization of values
# We will walk through the first two.

# %%
# In the adult dataset, 'maritalstatus' and 'relationship' look very closely related. Let's see if we need both of them.
household=adult3[['relationship', 'maritalstatus']]
household.groupby('relationship').sum()
# Out:
#                                                     maritalstatus
# relationship
# Husband         Married-civ-spouseMarried-civ-spouseMarried-ci...
# Not-in-family   Never-marriedDivorcedMarried-spouse-absentNeve...
# Other-relative  Married-civ-spouseNever-marriedNever-marriedNe...
# Own-child       Never-marriedNever-marriedNever-marriedNever-m...
# Unmarried       Never-marriedDivorcedSeparatedDivorcedNever-ma...
# Wife            Married-civ-spouseMarried-civ-spouseMarried-AF...

# %%
# Looks like 'relationship' may not have been the correct aggregator. Let's try 'maritalstatus'
household.groupby('maritalstatus').sum()
# Out:
#                                                             relationship
# maritalstatus
# Divorced               Not-in-familyUnmarriedUnmarriedNot-in-familyOw...
# Married-AF-spouse      WifeWifeWifeHusbandHusbandHusbandWifeOwn-child...
# Married-civ-spouse     HusbandHusbandWifeWifeHusbandHusbandHusbandHus...
# Married-spouse-absent  Not-in-familyNot-in-familyUnmarriedNot-in-fami...
# Never-married          Not-in-familyNot-in-familyOwn-childNot-in-fami...
# Separated              UnmarriedUnmarriedOwn-childUnmarriedOther-rela...
# Widowed                UnmarriedUnmarriedNot-in-familyNot-in-familyUn...

# %%
# Let's try setting a matrix that shows all unique combinations of 'relationship' and 'maritalstatus'.
# We will use relationship as index and use apply and lambda to sort maritalstatus according to that index.
household2 = household.groupby('relationship').apply(lambda x: x['maritalstatus'].unique())
household2
# Out:
# relationship
# Husband                     [Married-civ-spouse, Married-AF-spouse]
# Not-in-family     [Never-married, Divorced, Married-spouse-absen...
# Other-relative    [Married-civ-spouse, Never-married, Separated,...
# Own-child         [Never-married, Divorced, Married-civ-spouse, ...
# Unmarried         [Never-married, Divorced, Separated, Widowed, ...
# Wife                        [Married-civ-spouse, Married-AF-spouse]
# dtype: object

# %%
# Can you turn this around and use 'maritalstatus' as index?

# %% [markdown]
# Oof. It seems that 'relationship' and 'maritalstatus' are related as subcategories of one another. Unless we join them into the same attribute and create one level per combination, we will need to keep both columns.

# %%
# Let's see if 'educationyears' and 'education' are more interchangeable.
degree=adult3[['educationyears', 'education']]
# degree.sort_values('educationyears')  # This gives us the entire list sorted, but we want to display the unique values
# degree.groupby('educationyears').sum() # That's what we had before--we can do better!
# Let's try setting a matrix that is indexed by educationyears. This is what apply and lambda x do. 
degree2 = degree.groupby('educationyears').apply(lambda x: x['education'].unique())
degree2
# Out:
# educationyears
# 1        [Preschool]
# 2          [1st-4th]
# 3          [5th-6th]
# 4          [7th-8th]
# 5              [9th]
# 6             [10th]
# 7             [11th]
# 8             [12th]
# 9          [HS-grad]
# 10    [Some-college]
# 11       [Assoc-voc]
# 12      [Assoc-acdm]
# 13       [Bachelors]
# 14         [Masters]
# 15     [Prof-school]
# 16       [Doctorate]
# dtype: object

# %%
# Can you turn this around and use 'education' as index?

# %% [markdown]
# In contrast to 'maritalstatus' and 'relationship, it seems that 'educationyears' and 'education' are unqiuely related. This means we need only one of these columns. Since working with numbers is always easier, we choose 'educationyears' and will eliminate 'education'.
# To drop a columns, we can use a couple of methods:
# 1. We can rebuild the dataframe (or a different dataframe) with only the columsn that we want, for example: adult4=adult3[['age','race','sex','educationyears','income']]--that kind of thing
# 2. We can use the pandas drop function as explained here: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html. Another explanation with a data frame sample is here: http://cmdlinetips.com/2018/04/how-to-drop-one-or-more-columns-in-pandas-dataframe/.  This is a better way to modify your dataframe.

# %%
# Build an adult4 dataframe that contains all columns of the adult3 dataframe EXCEPT 'education'

# %% [markdown]
# Rows can also be removed using the “drop” function, by specifying axis=0. Drop() removes rows based on “labels”, rather than numeric indexing. To delete rows based on their numeric position / index, use iloc to reassign the dataframe values, as in the examples below.
# Delete the rows with labels 0,1,5
# >>adult5 = adult3.drop([0,1,2], axis=0)
# Delete the rows with label 'white'
# For label-based deletion, set the index first on the dataframe:
# >>adult5 = adult3.set_index('race')
# >>adult5 = adult3.drop('white', axis=0). # Delete all rows with label 'white'
# Delete the first five rows using iloc selector
# >>adult5 = adult3.iloc[5:,]

# %%
# Build an adult5 dataframe that contains only rows of non-white races

# %% [markdown]
# ## Discretization
# In the 'workclass' attribute, we have 9 categories. Can we reduce those to the following:
# - Unknown--contains all Unknown, Never-worked, and Without-pay
# - Government--contains all Federal, State, and Local government employees
# - Self--contains all self-employed groups

# %%
# You already know how to replace strings, try this here with the Unknown category!

# %%
# Research another way to craete subgroups (hint: consult the R file for this week) and apply this to the Self category.

# %% [markdown]
# For Government, would binning be the correct strategy? https://stackoverflow.com/questions/45273731/binning-column-with-python-pandas. If not, what other attribute in the dataframe could lend itself to binning?

# %%
# Use your favorite strategy to work with the Government category.
